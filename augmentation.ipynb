# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import random

# %% [markdown]
# # Data Augmentation Pipeline

# %%
ugmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),     # Random horizontal flip
    tf.keras.layers.RandomRotation(0.1),          # Random rotation
    tf.keras.layers.RandomBrightness(0.2),        # Adjust brightness
    tf.keras.layers.RandomZoom(0.1),              # Random zoom
])

# %%
data_dir = "../data/Face Mask Dataset/Train/WithMask"

# Select a random image from the dataset
img_path = os.path.join(data_dir, random.choice(os.listdir(data_dir)))

# Load and resize the image
img = tf.keras.preprocessing.image.load_img(img_path, target_size=(224, 224))

# Convert image to array format
img_array = tf.keras.preprocessing.image.img_to_array(img)

# Add batch dimension (required for TensorFlow)
img_array = tf.expand_dims(img_array, 0)

# %%
plt.figure(figsize=(10,5))

# original
plt.subplot(1,5,1)
plt.imshow(img)
plt.title("Original")
plt.axis("off")

# augmented
for i in range(4):
    augmented = data_augmentation(img_array)
    # Normalize for proper visualization
    plt.subplot(1,5,i+2)
    plt.imshow(augmented[0].numpy() / 255)
    plt.title("Augmented")
    plt.axis("off")

plt.show()
